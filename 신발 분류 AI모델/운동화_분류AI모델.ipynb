# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get update -qq && apt-get install fonts-nanum* -qq

# %%
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정하기
fontpath = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'  # 폰트 경로 변경: 'NanumBarunGothic'에서 'NanumGothic'으로 변경
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumGothic')  # 폰트 설정 변경: 'NanumBarunGothic'에서 'NanumGothic'으로 변경
plt.rc('axes', unicode_minus=False)  # 유니코드에서 음수 부호 설정
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-525
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
# 필요한 라이브러리 설치하기
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# fatal: destination path 'bing_image_downloader' already exists and is not an empty directory.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# 한글이 포함된 간단한 차트 그리기
plt.plot([1, 2, 3], [1, 2, 3])
plt.xlabel("x축")
plt.ylabel("y축")
plt.title("간단한 차트 예시")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# 필요한 라이브러리 설치하기
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# fatal: destination path 'bing_image_downloader' already exists and is not an empty directory.

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 만들기
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습 데이터와 평가 데이터로 구분하는 함수 query는 키워드

def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비하기
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = 'nike sneakers'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://worthly.com/wp-content/uploads/2014/11/139517568.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://cdnb.lystit.com/photos/b31c-2014/05/29/nike-yellow-internationalist-sneakers-product-1-20450561-3-740272117-normal.jpeg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (http://louiebcaponga.weebly.com/uploads/2/7/0/9/27090703/s603024784485489931_p1_i2_w1600.jpeg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https://cdnb.lystit.com/photos/2013/08/07/nike-blackvarsity-redwhite-sweet-classic-leather-high-top-sneakers-product-2-10346662-117380877.jpeg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://cdna.lystit.com/photos/2013/08/07/nike-blackvarsity-redwhite-sweet-classic-leather-high-top-sneakers-product-1-10346662-141973395.jpeg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://www.bluelilyandblue.com/images/large/nike sneakers for men-838jlf.jpg)
# ...

# %%
query = 'addidas sneakers'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://4.bp.blogspot.com/-PKLvGmPzWn8/Tz3iUwonF2I/AAAAAAAAAIo/6T3zlIBhJ3o/s1600/adidas+running+shoes.jpg)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://cdna.lystit.com/photos/2013/08/31/adidas-pride-ink-iron-black-originals-hardcourt-hi-casual-sneakers-product-1-13191883-388339869.jpeg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://cdnd.lystit.com/photos/b98e-2013/12/17/adidas--mens-originals-samoa-sneakers-from-finish-line-product-1-12521820-0-491273823-normal.jpeg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://cdna.lystit.com/photos/2013/09/23/adidas-blast-emerardblaze-pink-hardcourt-high-top-casual-sneakers-product-1-13652945-861889368.jpeg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://s3-eu-west-1.amazonaws.com/images.linnlive.com/5a541fda88a1e3d6627ec69c00f668dd/37395700-9f16-4305-8ef3-f2664cc4e4ba.jpg)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (http://images.esellerpro.com/3656/I/953/D65665.jpg)
# ...

# %%
query = 'newbalance sneakers'
downloader.download(query, limit=40,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 30)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 이미지 다운로드 (https://www.sneakersnstuff.com/images/142004/original.jpg)
# [Error] Invalid image, not saving https://www.sneakersnstuff.com/images/142004/original.jpg
# [Info] Issue getting: https://www.sneakersnstuff.com/images/142004/original.jpg
# [Error] No active exception to reraise
# #1 이미지 다운로드 (https://i0.wp.com/flawlesscrowns.com/wp-content/uploads/2020/03/New-Balance-997-Multi-Color-Sneaker-6-scaled.jpg?fit=2560%2C1709&amp;ssl=1)
# [Info] Issue getting: https://i0.wp.com/flawlesscrowns.com/wp-content/uploads/2020/03/New-Balance-997-Multi-Color-Sneaker-6-scaled.jpg?fit=2560%2C1709&amp;ssl=1
# [Error] HTTP Error 404: Not Found
# #1 이미지 다운로드 (http://image.sportsmansguide.com/adimgs/l/1/125540_ts.jpg)
# [Info] Issue getting: http://image.sportsmansguide.com/adimgs/l/1/125540_ts.jpg
# [Error] HTTP Error 403: Forbidden
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device 객체

# %%
# 데이터셋을 불러올 때 사용할 변형(transformation) 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './custom_dataset'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('size of learned dataset:', len(train_datasets))
print('size of test dataset:', len(test_datasets))

class_names = train_datasets.classes
print('class:', class_names)
# Out:
# size of learned dataset: 112
# size of test dataset: 37
# class: ['addidas sneakers', 'newbalance sneakers', 'nike sneakers']
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제하기
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs = 50
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복하며
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# #0 Loss: 1.2296 Acc: 41.9643% Time: 9.5597s
# #1 Loss: 0.5187 Acc: 81.2500% Time: 15.3673s
# #2 Loss: 0.4577 Acc: 83.0357% Time: 23.1355s
# #3 Loss: 0.5012 Acc: 81.2500% Time: 29.2223s
# #4 Loss: 0.3450 Acc: 90.1786% Time: 35.7812s
# #5 Loss: 0.3309 Acc: 84.8214% Time: 43.2025s
# #6 Loss: 0.2552 Acc: 91.0714% Time: 49.0808s
# #7 Loss: 0.3021 Acc: 89.2857% Time: 57.3244s
# #8 Loss: 0.2826 Acc: 87.5000% Time: 63.1439s
# #9 Loss: 0.2682 Acc: 92.8571% Time: 71.4261s
# #10 Loss: 0.2510 Acc: 93.7500% Time: 77.1638s
# #11 Loss: 0.4144 Acc: 86.6071% Time: 84.2861s
# #12 Loss: 0.1826 Acc: 92.8571% Time: 90.9308s
# #13 Loss: 0.2851 Acc: 93.7500% Time: 96.9160s
# #14 Loss: 0.1588 Acc: 93.7500% Time: 104.6241s
# #15 Loss: 0.1291 Acc: 93.7500% Time: 110.3150s
# #16 Loss: 0.1298 Acc: 96.4286% Time: 118.5273s
# #17 Loss: 0.0703 Acc: 98.2143% Time: 124.4232s
# #18 Loss: 0.0966 Acc: 95.5357% Time: 132.1514s
# #19 Loss: 0.0286 Acc: 100.0000% Time: 138.2798s
# ...

# %%
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[expected result: {class_names[preds[0]]}] (correct anser : {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='expected result: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# [expected result: addidas sneakers] (correct anser : addidas sneakers)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
from PIL import Image


image = Image.open('/content/drive/MyDrive/테스트이미지파일/ss.jpg')
image = transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image)
    _, preds = torch.max(outputs, 1)

# %%
# 필요한 라이브러리 설치하기
# !pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import io
from flask_ngrok import run_with_ngrok
from flask import Flask, jsonify, request


# 이미지를 읽어 결과를 반환하는 함수
def get_prediction(image_bytes):
    image = Image.open(io.BytesIO(image_bytes))
    image = transforms_test(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image)
        _, preds = torch.max(outputs, 1)
        imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    return class_names[preds[0]]


app = Flask(__name__)


@app.route('/', methods=['POST'])
def predict():
    if request.method == 'POST':
        # 이미지 바이트 데이터 받아오기
        file = request.files['file']
        image_bytes = file.read()

        # 분류 결과 확인 및 클라이언트에게 결과 반환
        class_name = get_prediction(image_bytes=image_bytes)
        print("결과:", {'class_name': class_name})
        return jsonify({'class_name': class_name})
